# %%
import statsbomb as sb

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
comp = sb.Competitions()
##eve = sb.Events()
##lin = sb.Lineups()
##mat = sb.Matches()

# %%
print(type(comp))
# Out:
# <class 'statsbomb.parser.Competitions'>

# %%
events = sb.Events(event_id='15946')
df = events.get_dataframe(event_type='shot')
print(len(df))
print(type(df))
df.head(20)
# Out:
# 28
# <class 'pandas.core.frame.DataFrame'>
#    event_type                                    id  index  period  \
# 0        shot  65f16e50-7c5d-4293-b2fc-d20887a772f9    148       1
# 1        shot  b0f73423-3990-45ae-9dda-3512c2d1aff3    283       1
# 2        shot  13b1ddab-d22e-43d9-bfe4-12632fea1a27    755       1
# 3        shot  391bfb74-07a6-4afe-9568-02a9b23f5bd4    788       1
# 4        shot  5e55f5a5-954f-4cc4-ba6e-a9cf6d6e249e    842       1
# 5        shot  1c0347cd-14dc-4aa8-91eb-520672a6cfe1   1395       1
# 6        shot  7c3182af-c8a8-4c7c-934e-5c41c7b93c6a   1621       1
# 7        shot  39f231e5-0072-461c-beb0-a9bedb420f83   1666       1
# 8        shot  062cdd08-8773-424f-8fc5-2e3d441c3c5c   1670       1
# 9        shot  c09e904d-6c8e-479d-af2e-c2c5863aca71   1700       1
# 10       shot  9eda2385-88bb-4c37-b039-a738c4cd8d4b   1764       1
# 11       shot  0b56df83-958e-4a31-9e5a-d741b4bf95cf   1870       1
# ...

# %%
print(df.columns)
# Out:
# Index(['event_type', 'id', 'index', 'period', 'timestamp', 'minute', 'second',
#        'possession', 'possession_team', 'play_pattern', 'off_camera', 'team',
#        'player', 'position', 'duration', 'under_pressure', 'recipient',
#        'length', 'angle', 'height', 'outcome', 'type', 'body_part',
#        'assisted_shot_id', 'pass_backheel', 'deflected', 'miscommunication',
#        'through_ball', 'cross', 'cut_back', 'switch', 'shot_assist',
#        'goal_assist', 'start_location_x', 'start_location_y', 'end_location_x',
#        'end_location_y'],
#       dtype='object')
